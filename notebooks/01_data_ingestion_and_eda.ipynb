# %%
pip install seaborn pandas matplotlib numpy faker
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
#      ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#      --- ------------------------------------ 0.2/2.0 MB 5.9 MB/s eta 0:00:01
#      -------------- ------------------------- 0.7/2.0 MB 9.1 MB/s eta 0:00:01
#      -------------------- ------------------- 1.0/2.0 MB 9.4 MB/s eta 0:00:01
#      -------------------------------- ------- 1.6/2.0 MB 10.3 MB/s eta 0:00:01
#      ---------------------------------------  2.0/2.0 MB 10.5 MB/s eta 0:00:01
#      ---------------------------------------- 2.0/2.0 MB 9.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to write executable - trying to use .deleteme logic
# ERROR: Could not install packages due to an OSError: [WinError 2] The system cannot find the file specified: 'c:\\Python310\\Scripts\\faker.exe' -> 'c:\\Python310\\Scripts\\faker.exe.deleteme'
#
#
# ...

# %%
pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 01_data_ingestion_and_eda.ipynb

# ========================================
# 🧠 Step 1: Data Ingestion & Preparation
# ========================================

import pandas as pd
import numpy as np

# Load dataset
df = pd.read_csv("../data/adtech_campaign_performance.csv", parse_dates=["date"])
print("✅ Data loaded successfully!")
print("\nDataset shape:", df.shape)

# Check for missing values
print("\nMissing values:")
print(df.isnull().sum())

# ---- Data Overview ----
print("\nSample records:")
print(df.head())

print("\nColumn Data Types:")
print(df.dtypes)

# ========================================
# ✨ Step 2: Feature Engineering (Derived Metrics)
# ========================================

# Add Key Performance Metrics
df["CTR"] = (df["clicks"] / df["impressions"]) * 100  # Click-through rate
df["CVR"] = (df["conversions"] / df["clicks"]).replace([np.inf, np.nan], 0) * 100  # Conversion rate
df["CPC"] = (df["cost"] / df["clicks"]).replace([np.inf, np.nan], 0)  # Cost per click
df["Cost_per_Conversion"] = (df["cost"] / df["conversions"]).replace([np.inf, np.nan], 0)

print("\n✅ Derived metrics added (CTR, CVR, CPC, Cost per Conversion)")
print(df.describe())

# Save cleaned dataset for next steps
df.to_csv("../data/adtech_campaign_cleaned.csv", index=False)
print("\n💾 Cleaned dataset saved as 'adtech_campaign_cleaned.csv'")
# Out:
# ✅ Data loaded successfully!
#
# Dataset shape: (4550, 9)
#
# Missing values:
# campaign_id     0
# date            0
# impressions     0
# clicks          0
# conversions     0
# cost            0
# bid_strategy    0
# device          0
# region          0
# dtype: int64
#
# Sample records:
#   campaign_id       date  impressions  clicks  conversions     cost  \
# 0        C001 2024-01-01       126958    2151           74  8859.46
# 1        C001 2024-01-02       173266    2059           96  3235.65
# 2        C001 2024-01-03         5769      91            8    91.28
# 3        C001 2024-01-04        90305    1162           63  2515.63
# 4        C001 2024-01-05       154503    1449           71  4092.38
#
#   bid_strategy   device         region
# 0          CPC   Tablet         Europe
# 1          CPA  Desktop  North America
# 2          CPC   Mobile  South America
# 3          CPA   Tablet         Europe
# 4          CPA  Desktop           Asia
#
# Column Data Types:
# ...
